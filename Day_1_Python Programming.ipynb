# %% [markdown]
# # Python Programming

# %% [markdown]
# ## Day 1 of the programming

# %%
print("Hello IIT");
# Out:
# Hello IIT

# %%
print("Hello Sri Lanka\nHow are you?");
# Out:
# Hello Sri Lanka
# How are you?

# %% [markdown]
# # This line is coded by S

# %% [markdown]
# ## This is the size 2

# %% [markdown]
# ### This is the size 3

# %%
print("-----------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------

# %%
print(
"""
My Name is Seniru
Im a Student of the IIT
Currently im learning about the python basics
"""
);
# Out:
# My Name is Seniru
# Im a Student of the IIT
# Currently im learning about the python basics
